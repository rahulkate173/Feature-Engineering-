# %% [markdown]
# ### Importing Data visulation Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing data Frame

# %%
df=pd.read_csv("D:/OneDrive/Desktop/jupyter/Feature Enginerring/datasets/titanic.csv",usecols=['Fare','Age','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isna().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6328\1527141296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %% [markdown]
# # Now Doing Data Scaling

# %% [markdown]
# --> Scaling is done basicaly to transform our data what happen when we work with algorith based on method like gradient descent and eucliden distance then large value can lead to large distance and our main goal is to get the smallest distance between point
# Eg: P1(x1,y1)=(23,67)
#     P2(x2,y2)=(47,98)
# --> This distance is to large ,hence go to scale our data and this is the most importnat  part are goal of datascience

# %% [markdown]
# ### 1. Standardziation and Normalization

# %% [markdown]
# transforming is done by considering mean(|U=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()

# %%
# scalar.fit_transform(df)
df_scaled=pd.DataFrame(scalar.fit_transform(df),columns=df.columns)
df_scaled
# Out:
#      Survived       Age      Fare
# 0   -0.789272 -0.565736 -0.502445
# 1    1.266990  0.663861  0.786845
# 2    1.266990 -0.258337 -0.488854
# 3    1.266990  0.433312  0.420730
# 4   -0.789272  0.433312 -0.486337
# ..        ...       ...       ...
# 886 -0.789272 -0.181487 -0.386671
# 887  1.266990 -0.796286 -0.044381
# 888 -0.789272 -0.104637 -0.176263
# 889  1.266990 -0.258337 -0.044381
# 890 -0.789272  0.202762 -0.492378
#
# [891 rows x 3 columns]

# %%
# %matplotlib inline

# %%
plt.hist(df['Age'],bins=20)
# Out:
# (array([ 40.,  14.,  15.,  31.,  79.,  98., 262.,  84.,  73.,  45.,  35.,
#          35.,  29.,  16.,  13.,  11.,   4.,   5.,   1.,   1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_scaled['Age'],bins=20)
# Out:
# (array([ 40.,  14.,  15.,  31.,  79.,  98., 262.,  84.,  73.,  45.,  35.,
#          35.,  29.,  16.,  13.,  11.,   4.,   5.,   1.,   1.]),
#  array([-2.22415608, -1.91837055, -1.61258503, -1.3067995 , -1.00101397,
#         -0.69522845, -0.38944292, -0.08365739,  0.22212813,  0.52791366,
#          0.83369919,  1.13948471,  1.44527024,  1.75105577,  2.05684129,
#          2.36262682,  2.66841235,  2.97419787,  3.2799834 ,  3.58576892,
#          3.89155445]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_scaled['Fare'],bins=20)
# Out:
# (array([562., 170.,  67.,  39.,  15.,  16.,   2.,   0.,   9.,   2.,   6.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   3.]),
#  array([-0.64842165, -0.13264224,  0.38313716,  0.89891657,  1.41469598,
#          1.93047539,  2.4462548 ,  2.96203421,  3.47781362,  3.99359303,
#          4.50937244,  5.02515184,  5.54093125,  6.05671066,  6.57249007,
#          7.08826948,  7.60404889,  8.1198283 ,  8.63560771,  9.15138712,
#          9.66716653]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### 2. Miinimun And Maximum Scaler

# %% [markdown]
# It Scales the data between range of 0 to 1
#
# X_SCALED=(X - X_min)/(X_max - X_min)

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
df_scaledMinMax=pd.DataFrame(scalar.fit_transform(df),columns=df.columns)
df_scaledMinMax.head()
# Out:
#    Survived       Age      Fare
# 0       0.0  0.271174  0.014151
# 1       1.0  0.472229  0.139136
# 2       1.0  0.321438  0.015469
# 3       1.0  0.434531  0.103644
# 4       0.0  0.434531  0.015713

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
ax[0].hist(df['Age'],bins=20)
ax[1].hist(df_scaledMinMax['Age'],bins=20)
# Out:
# (array([ 40.,  14.,  15.,  31.,  79.,  98., 262.,  84.,  73.,  45.,  35.,
#          35.,  29.,  16.,  13.,  11.,   4.,   5.,   1.,   1.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# identity maintained just scaled down

# %%
fig,ax=plt.subplots(1,2,figsize=(10,4))
sns.histplot(df['Fare'],bins=20,ax=ax[0],kde=True)
sns.histplot(df_scaledMinMax['Fare'],bins=20,ax=ax[1],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# ### 3. Robust Scalar

# %% [markdown]
# It is use to scale the feature to median and quantile

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler=RobustScaler()
df_robustScaled=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
df_robustScaled.head()
# Out:
#    Survived       Age      Fare
# 0       0.0 -0.461538 -0.312011
# 1       1.0  0.769231  2.461242
# 2       1.0 -0.153846 -0.282777
# 3       1.0  0.538462  1.673732
# 4       0.0  0.538462 -0.277363

# %%
fig,ax=plt.subplots(2,3,figsize=(10,6))
sns.histplot(df_robustScaled['Survived'],bins=20,ax=ax[0][0],kde=True)
sns.histplot(df_robustScaled['Age'],bins=20,ax=ax[0][1],kde=True)
sns.histplot(df_robustScaled['Fare'],bins=20,ax=ax[0][2],kde=True)
sns.histplot(df['Survived'],bins=20,ax=ax[1][0],kde=True)
sns.histplot(df['Age'],bins=20,ax=ax[1][1],kde=True)
sns.histplot(df['Fare'],bins=20,ax=ax[1][2],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# So form robust scaling what happend all the thing are preserved just values are scaled down and it is important for machine accuracy

# %% [markdown]
# ### NORMAL/GUASSIAN TRANSFORMATION

# %% [markdown]
# ### 1. Logarthimic Transformation

# %% [markdown]
# skewed distribution is converted to normal distribution

# %%
import pylab
import scipy.stats as stat

# %%
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(df[feature],bins=20,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(df,'Fare')

# %% [markdown]
# --> Not good because not much more or data points are on line(red)

# %%
plot_data(df,'Age')

# %% [markdown]
# --> It is good

# %%
df['Log_Fare']=np.log1p(df['Fare'])
plot_data(df,'Log_Fare')

# %% [markdown]
# --> Used log1p() Beacause it is containing zero(0) value log(0)=infinity

# %%
df['Age_log']=np.log1p(df['Age'])
plot_data(df,'Age_log')
#noramlly skewed data is not left skewed

# %% [markdown]
# ### 2.Reciprocal transformation

# %%
df['Fare_reciprocal']=1/df['Fare']
plot_data(df,'Fare_reciprocal')
# Out:
# C:\Users\Rahul\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:2767: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %% [markdown]
# ### 3. Squareroot Transformation

# %%
df['Fare_Sqroot']=df['Fare']**(0.5)
plot_data(df,'Fare_Sqroot')

# %%
df['Age_sqrt']=df['Age']**(0.5)
plot_data(df,'Age_sqrt')

# %% [markdown]
# --> Okay,that is good

# %% [markdown]
# ### 4. Exponential Transformation

# %%
df['Fare_exp']=df.Fare**(1/1.2)
plot_data(df,'Fare_exp')

# %%
df['Age_exp']=df.Age**(1/1.2)
plot_data(df,'Age_exp')

# %% [markdown]
# ### 5. Box Cox Transformation

# %% [markdown]
#     T(y)=(y.exp(l)-1)/l
#
#     - l:lambda(parameter)
#     - y:response variable or what is given

# %%
df['Age_boxcox'],parameter=stat.boxcox(df['Age'])
plot_data(df,'Age_boxcox')

# %%
df.Fare[df.Fare==0]=1
df['Fare_boxcox'],parameter=stat.boxcox(df['Fare'])
plot_data(df,'Fare_boxcox')
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6328\1019142084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Fare[df.Fare==0]=1
